# %% [markdown]
# # 1:Understand The Data

# %% [markdown]
# **1.1:Importing Libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("D:\dailyActivity_merged.csv")

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %% [markdown]
# **Data Size**

# %%
df.shape
# Out:
# (457, 15)

# %% [markdown]
# **Data Preview**

# %%
# Display The first few rows of the dataset
df.head(5)
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    3/25/2016       11004           7.11             7.11
# 1  1503960366    3/26/2016       17609          11.55            11.55
# 2  1503960366    3/27/2016       12736           8.53             8.53
# 3  1503960366    3/28/2016       13231           8.93             8.93
# 4  1503960366    3/29/2016       12041           7.85             7.85
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                2.57                      0.46
# 1                       0.0                6.92                      0.73
# 2                       0.0                4.66                      0.16
# 3                       0.0                3.19                      0.79
# 4                       0.0                2.16                      1.09
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                 4.07                      0.0                 33
# 1                 3.91                      0.0                 89
# 2                 3.71                      0.0                 56
# 3                 4.95                      0.0                 39
# 4                 4.61                      0.0                 28
#
#    FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                   12                   205               804      1819
# 1                   17                   274               588      2154
# 2                    5                   268               605      1944
# 3                   20                   224              1080      1932
# 4                   28                   243               763      1886

# %% [markdown]
# **Data Types**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 15 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Id                        457 non-null    int64
#  1   ActivityDate              457 non-null    object
#  2   TotalSteps                457 non-null    int64
#  3   TotalDistance             457 non-null    float64
#  4   TrackerDistance           457 non-null    float64
#  5   LoggedActivitiesDistance  457 non-null    float64
#  6   VeryActiveDistance        457 non-null    float64
#  7   ModeratelyActiveDistance  457 non-null    float64
#  8   LightActiveDistance       457 non-null    float64
#  9   SedentaryActiveDistance   457 non-null    float64
#  10  VeryActiveMinutes         457 non-null    int64
#  11  FairlyActiveMinutes       457 non-null    int64
#  12  LightlyActiveMinutes      457 non-null    int64
#  13  SedentaryMinutes          457 non-null    int64
#  14  Calories                  457 non-null    int64
# dtypes: float64(7), int64(7), object(1)
# memory usage: 53.7+ KB

# %%
df.dtypes
# Out:
# Id                            int64
# ActivityDate                 object
# TotalSteps                    int64
# TotalDistance               float64
# TrackerDistance             float64
# LoggedActivitiesDistance    float64
# VeryActiveDistance          float64
# ModeratelyActiveDistance    float64
# LightActiveDistance         float64
# SedentaryActiveDistance     float64
# VeryActiveMinutes             int64
# FairlyActiveMinutes           int64
# LightlyActiveMinutes          int64
# SedentaryMinutes              int64
# Calories                      int64
# dtype: object

# %% [markdown]
# **Missing Values:**

# %%
df.isna().sum()
# Out:
# Id                          0
# ActivityDate                0
# TotalSteps                  0
# TotalDistance               0
# TrackerDistance             0
# LoggedActivitiesDistance    0
# VeryActiveDistance          0
# ModeratelyActiveDistance    0
# LightActiveDistance         0
# SedentaryActiveDistance     0
# VeryActiveMinutes           0
# FairlyActiveMinutes         0
# LightlyActiveMinutes        0
# SedentaryMinutes            0
# Calories                    0
# dtype: int64

# %%
df.isna().mean() * 100
# Out:
# Id                          0.0
# ActivityDate                0.0
# TotalSteps                  0.0
# TotalDistance               0.0
# TrackerDistance             0.0
# LoggedActivitiesDistance    0.0
# VeryActiveDistance          0.0
# ModeratelyActiveDistance    0.0
# LightActiveDistance         0.0
# SedentaryActiveDistance     0.0
# VeryActiveMinutes           0.0
# FairlyActiveMinutes         0.0
# LightlyActiveMinutes        0.0
# SedentaryMinutes            0.0
# Calories                    0.0
# dtype: float64

# %% [markdown]
# **Statistical Overview**

# %%
df.describe().T
# Out:
#                           count          mean           std           min  \
# Id                        457.0  4.628595e+09  2.293781e+09  1.503960e+09
# TotalSteps                457.0  6.546562e+03  5.398493e+03  0.000000e+00
# TotalDistance             457.0  4.663523e+00  4.082072e+00  0.000000e+00
# TrackerDistance           457.0  4.609847e+00  4.068540e+00  0.000000e+00
# LoggedActivitiesDistance  457.0  1.794274e-01  8.492318e-01  0.000000e+00
# VeryActiveDistance        457.0  1.180897e+00  2.487159e+00  0.000000e+00
# ModeratelyActiveDistance  457.0  4.786433e-01  8.309952e-01  0.000000e+00
# LightActiveDistance       457.0  2.890197e+00  2.237523e+00  0.000000e+00
# SedentaryActiveDistance   457.0  1.903720e-03  8.486801e-03  0.000000e+00
# VeryActiveMinutes         457.0  1.662363e+01  2.891970e+01  0.000000e+00
# FairlyActiveMinutes       457.0  1.307002e+01  3.620864e+01  0.000000e+00
# LightlyActiveMinutes      457.0  1.700700e+02  1.222054e+02  0.000000e+00
# SedentaryMinutes          457.0  9.952823e+02  3.370214e+02  3.200000e+01
# Calories                  457.0  2.189453e+03  8.154845e+02  0.000000e+00
#
#                                    25%           50%           75%  \
# Id                        2.347168e+09  4.057193e+09  6.391747e+09
# TotalSteps                1.988000e+03  5.986000e+03  1.019800e+04
# TotalDistance             1.410000e+00  4.090000e+00  7.160000e+00
# TrackerDistance           1.280000e+00  4.090000e+00  7.110000e+00
# LoggedActivitiesDistance  0.000000e+00  0.000000e+00  0.000000e+00
# VeryActiveDistance        0.000000e+00  0.000000e+00  1.310000e+00
# ModeratelyActiveDistance  0.000000e+00  2.000000e-02  6.700000e-01
# LightActiveDistance       8.700000e-01  2.930000e+00  4.460000e+00
# SedentaryActiveDistance   0.000000e+00  0.000000e+00  0.000000e+00
# VeryActiveMinutes         0.000000e+00  0.000000e+00  2.500000e+01
# FairlyActiveMinutes       0.000000e+00  1.000000e+00  1.600000e+01
# LightlyActiveMinutes      6.400000e+01  1.810000e+02  2.570000e+02
# SedentaryMinutes          7.280000e+02  1.057000e+03  1.285000e+03
# Calories                  1.776000e+03  2.062000e+03  2.667000e+03
#
#                                    max
# Id                        8.877689e+09
# TotalSteps                2.849700e+04
# TotalDistance             2.753000e+01
# TrackerDistance           2.753000e+01
# LoggedActivitiesDistance  6.727057e+00
# VeryActiveDistance        2.192000e+01
# ModeratelyActiveDistance  6.400000e+00
# LightActiveDistance       1.251000e+01
# SedentaryActiveDistance   1.000000e-01
# VeryActiveMinutes         2.020000e+02
# FairlyActiveMinutes       6.600000e+02
# LightlyActiveMinutes      7.200000e+02
# SedentaryMinutes          1.440000e+03
# Calories                  4.562000e+03

# %% [markdown]
# **Duplicate Data**

# %%
print("Total Duplicate values are:", df.duplicated().sum())
# Out:
# Total Duplicate values are: 0

# %% [markdown]
# **Exploring Diversity**

# %%
df.Id.nunique()
# Out:
# 35

# %% [markdown]
# # 2: Analysis & Visualizations

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0    1503960366    3/25/2016       11004       7.110000         7.110000
# 1    1503960366    3/26/2016       17609      11.550000        11.550000
# 2    1503960366    3/27/2016       12736       8.530000         8.530000
# 3    1503960366    3/28/2016       13231       8.930000         8.930000
# 4    1503960366    3/29/2016       12041       7.850000         7.850000
# ..          ...          ...         ...            ...              ...
# 452  8877689391     4/8/2016       23014      20.389999        20.389999
# 453  8877689391     4/9/2016       16470       8.070000         8.070000
# 454  8877689391    4/10/2016       28497      27.530001        27.530001
# 455  8877689391    4/11/2016       10622       8.060000         8.060000
# 456  8877689391    4/12/2016        2350       1.780000         1.780000
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                         0.0                2.57                      0.46
# 1                         0.0                6.92                      0.73
# 2                         0.0                4.66                      0.16
# 3                         0.0                3.19                      0.79
# 4                         0.0                2.16                      1.09
# ..                        ...                 ...                       ...
# 452                       0.0               11.10                      0.63
# 453                       0.0                0.00                      0.02
# 454                       0.0               21.92                      1.12
# 455                       0.0                1.47                      0.15
# 456                       0.0                0.00                      0.00
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 0                   4.07                     0.00                 33
# 1                   3.91                     0.00                 89
# 2                   3.71                     0.00                 56
# 3                   4.95                     0.00                 39
# 4                   4.61                     0.00                 28
# ..                   ...                      ...                ...
# 452                 8.62                     0.00                 70
# 453                 8.02                     0.00                 90
# 454                 4.46                     0.00                128
# 455                 6.37                     0.01                 18
# 456                 1.78                     0.00                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 15 columns]

# %%
cols = ['Id','ActivityDate','TotalSteps','VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes','Calories']
df = df[cols]

# %%
df
# Out:
#              Id ActivityDate  TotalSteps  VeryActiveMinutes  \
# 0    1503960366    3/25/2016       11004                 33
# 1    1503960366    3/26/2016       17609                 89
# 2    1503960366    3/27/2016       12736                 56
# 3    1503960366    3/28/2016       13231                 39
# 4    1503960366    3/29/2016       12041                 28
# ..          ...          ...         ...                ...
# 452  8877689391     4/8/2016       23014                 70
# 453  8877689391     4/9/2016       16470                 90
# 454  8877689391    4/10/2016       28497                128
# 455  8877689391    4/11/2016       10622                 18
# 456  8877689391    4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
# [457 rows x 8 columns]

# %%
df.rename(columns={'ActivityDate': 'date'},inplace=True)

# %%
df['TotalMinutes'] = df.VeryActiveMinutes + df.FairlyActiveMinutes + df.SedentaryMinutes + df.LightlyActiveMinutes

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  3/25/2016       11004                 33
# 1    1503960366  3/26/2016       17609                 89
# 2    1503960366  3/27/2016       12736                 56
# 3    1503960366  3/28/2016       13231                 39
# 4    1503960366  3/29/2016       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391   4/8/2016       23014                 70
# 453  8877689391   4/9/2016       16470                 90
# 454  8877689391  4/10/2016       28497                128
# 455  8877689391  4/11/2016       10622                 18
# 456  8877689391  4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes
# 0            1054
# 1             968
# 2             934
# 3            1363
# 4            1062
# ..            ...
# 452          1440
# 453          1440
# 454          1440
# 455          1440
# 456           589
#
# [457 rows x 9 columns]

# %%
df['TotalHours'] = round(df.TotalMinutes / 60)

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366  3/25/2016       11004                 33
# 1    1503960366  3/26/2016       17609                 89
# 2    1503960366  3/27/2016       12736                 56
# 3    1503960366  3/28/2016       13231                 39
# 4    1503960366  3/29/2016       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391   4/8/2016       23014                 70
# 453  8877689391   4/9/2016       16470                 90
# 454  8877689391  4/10/2016       28497                128
# 455  8877689391  4/11/2016       10622                 18
# 456  8877689391  4/12/2016        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours
# 0            1054        18.0
# 1             968        16.0
# 2             934        16.0
# 3            1363        23.0
# 4            1062        18.0
# ..            ...         ...
# 452          1440        24.0
# 453          1440        24.0
# 454          1440        24.0
# 455          1440        24.0
# 456           589        10.0
#
# [457 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    457 non-null    int64
#  1   date                  457 non-null    object
#  2   TotalSteps            457 non-null    int64
#  3   VeryActiveMinutes     457 non-null    int64
#  4   FairlyActiveMinutes   457 non-null    int64
#  5   LightlyActiveMinutes  457 non-null    int64
#  6   SedentaryMinutes      457 non-null    int64
#  7   Calories              457 non-null    int64
#  8   TotalMinutes          457 non-null    int64
#  9   TotalHours            457 non-null    float64
# dtypes: float64(1), int64(8), object(1)
# memory usage: 35.8+ KB

# %%
# Convert Date to datetime

df.date = pd.to_datetime(df.date)

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-03-25       11004                 33
# 1    1503960366 2016-03-26       17609                 89
# 2    1503960366 2016-03-27       12736                 56
# 3    1503960366 2016-03-28       13231                 39
# 4    1503960366 2016-03-29       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391 2016-04-08       23014                 70
# 453  8877689391 2016-04-09       16470                 90
# 454  8877689391 2016-04-10       28497                128
# 455  8877689391 2016-04-11       10622                 18
# 456  8877689391 2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours
# 0            1054        18.0
# 1             968        16.0
# 2             934        16.0
# 3            1363        23.0
# 4            1062        18.0
# ..            ...         ...
# 452          1440        24.0
# 453          1440        24.0
# 454          1440        24.0
# 455          1440        24.0
# 456           589        10.0
#
# [457 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 457 entries, 0 to 456
# Data columns (total 10 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    457 non-null    int64
#  1   date                  457 non-null    datetime64[ns]
#  2   TotalSteps            457 non-null    int64
#  3   VeryActiveMinutes     457 non-null    int64
#  4   FairlyActiveMinutes   457 non-null    int64
#  5   LightlyActiveMinutes  457 non-null    int64
#  6   SedentaryMinutes      457 non-null    int64
#  7   Calories              457 non-null    int64
#  8   TotalMinutes          457 non-null    int64
#  9   TotalHours            457 non-null    float64
# dtypes: datetime64[ns](1), float64(1), int64(8)
# memory usage: 35.8 KB

# %% [markdown]
# **DayOfWeek**

# %%
import datetime as dt

df['DayOfWeek'] = df.date.dt.day_name()

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-03-25       11004                 33
# 1    1503960366 2016-03-26       17609                 89
# 2    1503960366 2016-03-27       12736                 56
# 3    1503960366 2016-03-28       13231                 39
# 4    1503960366 2016-03-29       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391 2016-04-08       23014                 70
# 453  8877689391 2016-04-09       16470                 90
# 454  8877689391 2016-04-10       28497                128
# 455  8877689391 2016-04-11       10622                 18
# 456  8877689391 2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours DayOfWeek
# 0            1054        18.0    Friday
# 1             968        16.0  Saturday
# 2             934        16.0    Sunday
# 3            1363        23.0    Monday
# 4            1062        18.0   Tuesday
# ..            ...         ...       ...
# 452          1440        24.0    Friday
# 453          1440        24.0  Saturday
# 454          1440        24.0    Sunday
# 455          1440        24.0    Monday
# 456           589        10.0   Tuesday
#
# [457 rows x 11 columns]

# %%
df.describe().T
# Out:
#                       count                           mean  \
# Id                    457.0              4628594643.415755
# date                    457  2016-04-04 04:40:26.258205696
# TotalSteps            457.0                    6546.562363
# VeryActiveMinutes     457.0                      16.623632
# FairlyActiveMinutes   457.0                      13.070022
# LightlyActiveMinutes  457.0                     170.070022
# SedentaryMinutes      457.0                     995.282276
# Calories              457.0                    2189.452954
# TotalMinutes          457.0                    1195.045952
# TotalHours            457.0                      19.919037
#
#                                       min                  25%  \
# Id                           1503960366.0         2347167796.0
# date                  2016-03-12 00:00:00  2016-04-02 00:00:00
# TotalSteps                            0.0               1988.0
# VeryActiveMinutes                     0.0                  0.0
# FairlyActiveMinutes                   0.0                  0.0
# LightlyActiveMinutes                  0.0                 64.0
# SedentaryMinutes                     32.0                728.0
# Calories                              0.0               1776.0
# TotalMinutes                         41.0                985.0
# TotalHours                            1.0                 16.0
#
#                                       50%                  75%  \
# Id                           4057192912.0         6391747486.0
# date                  2016-04-05 00:00:00  2016-04-08 00:00:00
# TotalSteps                         5986.0              10198.0
# VeryActiveMinutes                     0.0                 25.0
# FairlyActiveMinutes                   1.0                 16.0
# LightlyActiveMinutes                181.0                257.0
# SedentaryMinutes                   1057.0               1285.0
# Calories                           2062.0               2667.0
# TotalMinutes                       1440.0               1440.0
# TotalHours                           24.0                 24.0
#
#                                       max                std
# Id                           8877689391.0  2293781429.648696
# date                  2016-04-12 00:00:00                NaN
# TotalSteps                        28497.0        5398.493064
# VeryActiveMinutes                   202.0          28.919704
# FairlyActiveMinutes                 660.0          36.208635
# LightlyActiveMinutes                720.0         122.205372
# SedentaryMinutes                   1440.0         337.021404
# Calories                           4562.0         815.484523
# TotalMinutes                       1440.0         306.457382
# TotalHours                           24.0           5.123904

# %% [markdown]
# **Histogram Day of Week**

# %%
plt.figure(figsize=(6,4))
plt.hist(df.DayOfWeek, bins=20, color='lightskyblue', width = 0.6)
plt.tight_layout()
plt.grid(True)

plt.xlabel('Day of Week',)
plt.ylabel('Freq')
plt.title('Freq by day of week')
plt.show()

# %%
df
# Out:
#              Id       date  TotalSteps  VeryActiveMinutes  \
# 0    1503960366 2016-03-25       11004                 33
# 1    1503960366 2016-03-26       17609                 89
# 2    1503960366 2016-03-27       12736                 56
# 3    1503960366 2016-03-28       13231                 39
# 4    1503960366 2016-03-29       12041                 28
# ..          ...        ...         ...                ...
# 452  8877689391 2016-04-08       23014                 70
# 453  8877689391 2016-04-09       16470                 90
# 454  8877689391 2016-04-10       28497                128
# 455  8877689391 2016-04-11       10622                 18
# 456  8877689391 2016-04-12        2350                  0
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 0                     12                   205               804      1819
# 1                     17                   274               588      2154
# 2                      5                   268               605      1944
# 3                     20                   224              1080      1932
# 4                     28                   243               763      1886
# ..                   ...                   ...               ...       ...
# 452                   29                   359               982      4196
# 453                    9                   289              1052      3841
# 454                   46                   211              1055      4526
# 455                    7                   225              1190      2820
# 456                    0                    58               531       938
#
#      TotalMinutes  TotalHours DayOfWeek
# 0            1054        18.0    Friday
# 1             968        16.0  Saturday
# 2             934        16.0    Sunday
# 3            1363        23.0    Monday
# 4            1062        18.0   Tuesday
# ..            ...         ...       ...
# 452          1440        24.0    Friday
# 453          1440        24.0  Saturday
# 454          1440        24.0    Sunday
# 455          1440        24.0    Monday
# 456           589        10.0   Tuesday
#
# [457 rows x 11 columns]

# %%
numeric_df = df.select_dtypes(include=[np.number])
sns.heatmap(numeric_df.corr())
# Out:
# <Axes: >

# %% [markdown]
# ### steps and calories

# %%
plt.figure(figsize=(8,6))
plt.scatter(df.TotalSteps, df.Calories, c = df.Calories)

median_steps = 5986
median_calories = 2062

plt.axhline(median_calories, color = 'blue', label = 'median of calories')
plt.axvline(median_steps, color = 'red', label = 'median of steps')

plt.xlabel('Steps')
plt.ylabel('Calories')
plt.title('Calories by total steps')
plt.legend()
plt.show()

# %% [markdown]
# ### Hours and calories

# %%
plt.figure(figsize=(8,6))
plt.scatter(df.TotalHours, df.Calories, c = df.Calories)

median_hours = 24
median_calories = 2062

plt.axhline(median_calories, color = 'blue', label = 'median of calories')
plt.axvline(median_hours, color = 'red', label = 'median of hours')

plt.xlabel('Hours')
plt.ylabel('Calories')
plt.title('Calories by total hours')
plt.legend()
plt.show()

# %% [markdown]
# ### The relationship between VeryActiveMinutes & FairlyActiveMinutes & LightlyActiveMinutes & SedentaryMinutes

# %%
VeryActiveMinutes = df.VeryActiveMinutes.sum()
FairlyActiveMinutes = df.FairlyActiveMinutes.sum()
LightlyActiveMinutes = df.LightlyActiveMinutes.sum()
SedentaryMinutes = df.SedentaryMinutes.sum()

minutes = [VeryActiveMinutes, FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes]
labels = ["VeryActiveMinutes", "FairlyActiveMinutes", "LightlyActiveMinutes", "SedentaryMinutes"]

plt.pie(minutes, labels=labels, autopct='%1.1f%%', explode = [0,0,0,0.1])
plt.show()
